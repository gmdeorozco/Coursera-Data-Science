# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_visits = np.array([1.0,2.0,50.0,30.0,100.0,70.0,20.0,10.0])
y_amount_spent = np.array([0.0, 0.0,1500,1200,3000,1500,300,300])
print(f"x_visits= {x_visits}")
print(f"y_amount_spent= {y_amount_spent}")
# Out:
# x_visits= [  1.   2.  50.  30. 100.  70.  20.  10.]
# y_amount_spent= [   0.    0. 1500. 1200. 3000. 1500.  300.  300.]

# %%
# m is the number of training examples
print(f"x_visits.shape: {x_visits.shape}")
m = x_visits.shape[0]
print(f"Number of training examples is: {m}")
# Out:
# x_visits.shape: (8,)
# Number of training examples is: 8

# %%
def compute_model_output(x, w, b):
    """
    Computes the prediction of a linear model
    Args:
      x (ndarray (m,)): Data, m examples 
      w,b (scalar)    : model parameters  
    Returns
      y (ndarray (m,)): target values
    """
    m = x.shape[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w * x[i] + b
        
    return f_wb

# %%
def compute_cost(x, y, w, b): 
    """
    Computes the cost function for linear regression.
    
    Args:
      x (ndarray (m,)): Data, m examples 
      y (ndarray (m,)): target values
      w,b (scalar)    : model parameters  
    
    Returns
        total_cost (float): The cost of using w,b as the parameters for linear regression
               to fit the data points in x and y
    """
    # number of training examples
    m = x.shape[0] 
    
    cost_sum = 0 
    for i in range(m): 
        f_wb = w * x[i] + b   
        cost = (f_wb - y[i]) ** 2  
        cost_sum = cost_sum + cost  
    total_cost = (1 / (2 * m)) * cost_sum  

    return total_cost

# %%
def all_costs():
    costs = np.zeros(100)
    w=0
    for i in range(100):
        costs[i] = compute_cost(x_visits, y_amount_spent, w, 0)
        w = w + 1
    return costs

def all_ws():
    ws = np.zeros(100)
    for i in range(100):
        ws[i] = i
    return ws

# %%
costs = all_costs()
print(costs)
ws = all_ws()
print(ws)
# Out:
# [ 945000.      880550.3125  818451.25    758702.8125  701305.
#   646257.8125  593561.25    543215.3125  495220.      449575.3125
#   406281.25    365337.8125  326745.      290502.8125  256611.25
#   225070.3125  195880.      169040.3125  144551.25    122412.8125
#   102625.       85187.8125   70101.25     57365.3125   46980.
#    38945.3125   33261.25     29927.8125   28945.       30312.8125
#    34031.25     40100.3125   48520.       59290.3125   72411.25
#    87882.8125  105705.      125877.8125  148401.25    173275.3125
#   200500.      230075.3125  262001.25    296277.8125  332905.
#   371882.8125  413211.25    456890.3125  502920.      551300.3125
#   602031.25    655112.8125  710545.      768327.8125  828461.25
#   890945.3125  955780.     1022965.3125 1092501.25   1164387.8125
#  1238625.     1315212.8125 1394151.25   1475440.3125 1559080.
#  1645070.3125 1733411.25   1824102.8125 1917145.     2012537.8125
#  2110281.25   2210375.3125 2312820.     2417615.3125 2524761.25
# ...

# %%
b=0
w_try = input('what w to use?')
# Out:
# what w to use?27

# %%
figure, axis = plt.subplots(2, 2)

# Plot the data points
axis[0, 0].scatter(x_visits, y_amount_spent, marker='x', c='r')

w_try = int(w_try)

# Plot the data points
axis[0, 1].scatter(w_try, compute_cost(x_visits,y_amount_spent,w_try,0 ), marker='x', c='r',label='Actual Values')
axis[0, 1].plot(ws,costs)

# Plot our model prediction
axis[1, 0].plot(x_visits,  compute_model_output(x_visits, w_try, b,), c='b',label='Our Prediction')

# Plot the data points
axis[1, 0].scatter(x_visits, y_amount_spent, marker='x', c='r',label='Actual Values')
